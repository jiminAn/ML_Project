# %% [markdown]
# # Disaster Tweet Classification wi
# ## NLP with Disaster Tweets
# ------------------
# ### GOAL
# - Predicting whether a given tweet is about a real disaster or not
# - if so, predict a `1`. if not, predict a `0`
#
#
# ### Reference
# - [competition main page](https://www.kaggle.com/c/nlp-getting-started)
# - [word2vec code](https://www.kaggle.com/slatawa/simple-implementation-of-word2vec)
# - [example code](https://www.kaggle.com/datarohitingole/disaster-tweet-classification-ridgeclassifiercv)
# - [comparing the performance of different Machine Learning Algorithm](https://dibyendudeb.com/comparing-machine-learning-algorithms/)

# %% [markdown]
# # 0. Importing Libraries

# %%
# for loading and preprocessing the data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re

# for training the model
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import tree, linear_model, neighbors, naive_bayes, ensemble
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# for evaluating classification model
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

# for data cleaning
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('punkt')

# for word2vec
import gensim
from gensim.models import Word2Vec

# Comparing all machine learning algorithms
from sklearn.metrics import mean_squared_error,confusion_matrix, precision_score, recall_score, auc,roc_curve
# Out:
# [nltk_data] Downloading package wordnet to /Users/mac/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/mac/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # 2. Data Preprocessing
# ## Contents
# #### 1. Clean the data
# - dealing with missing values
# - replace some commonly occuring shorthands
# - remove any characters other then alphabets
# - convert all dicitonary to lower case(for consistency)
# - lemmatize
#
# #### 2. word toeknization
#
# #### 3. Word2Vector

# %% [markdown]
# ## Data Description
# --------------
# ### Files
# - `train.csv` : the training set
# - `test.csv` : the test set
# - `sample_submission.csv` : a sample submission file in the correct format
#
# ### Columns
# - `id` : a unique identifier for each tweet
# - `text` : the text of the tweet
# - `location` : the location the tweet was sent from
# - `keyword` : a particular keyword from th tweet
# - `target` : in train.csv only, this denotes whether a tweet is about a real disaster(1) or not(0)

# %%
# loading the data set
data_path = './data/'
train = pd.read_csv(data_path + 'train.csv')
#test = pd.read_csv(data_path + 'test.csv')

#all_data = [train,test]

# %%
# split the data <train : test = 8 : 2>
train, test = train_test_split(train, test_size = 0.20, random_state = 0)

# %%
print('train_shape:', train.shape)
print('test_shape;', test.shape)
# Out:
# train_shape: (6090, 5)
# test_shape; (1523, 5)

# %%
train.head()
# Out:
#          id         keyword   location  \
# 1386   1999    bush%20fires        NaN
# 4048   5751  forest%20fires        NaN
# 3086   4428     electrocute        NaN
# 272     396      apocalypse   ColoRADo
# 7462  10678          wounds  Tampa, FL
#
#                                                    text  target
# 1386  Ted Cruz fires back at Jeb &amp; Bush: ÛÏWe l...       0
# 4048  This is the first year the Forest Service spen...       1
# 3086  @lightseraphs pissed at you and could have the...       0
# 272      I'm gonna fight Taylor as soon as I get there.       0
# 7462  @NicolaClements4 IÛªm not sure that covering ...       0

# %%
test.head()
# Out:
#         id         keyword                   location  \
# 311    454      armageddon              Wrigley Field
# 4970  7086        meltdown            Two Up Two Down
# 527    762       avalanche  Score Team Goals Buying @
# 6362  9094  suicide%20bomb                   Roadside
# 800   1160          blight        Laventillemoorings
#
#                                                    text  target
# 311   @KatieKatCubs you already know how this shit g...       0
# 4970  @LeMaireLee @danharmon People Near Meltdown Co...       0
# 527   1-6 TIX Calgary Flames vs COL Avalanche Presea...       0
# 6362  If you ever think you running out of choices i...       0
# 800   If you dotish to blight your car go right ahea...       0

# %% [markdown]
# ## 2-1. Clean the data
# - Dealing with Missing Values

# %%
all_data = [train,test]
for data in all_data:
    data.drop(["location", "id"], axis = 1, inplace = True)

# %%
# data prepocessing with regrex

def remove_URL(text): # remove url pattern in text
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)

def remove_html(text): # remove html pattern in text
    html = re.compile(r'<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    return html.sub(r'', text)
    #return re.sub(html, '', text)

def remove_punct(text): # remove punctuation in text: (;, ', ", :, ., , etc..)
  table = str.maketrans('', '', string.punctuation)
  return text.translate(table)

# %%
for data in all_data:
  data['text'] = data['text'].apply(lambda x: remove_URL(x))
  data['text'] = data['text'].apply(lambda x: remove_html(x))
  data['text'] = data['text'].apply(lambda x: remove_punct(x))

# %% [markdown]
# - Replace some commonly occuring shorthands

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"you'll", "you will", text)
    text = re.sub(r"i'll", "i will", text)
    text = re.sub(r"she'll", "she will", text)
    text = re.sub(r"he'll", "he will", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"there's", "there is", text)
    text = re.sub(r"here's", "here is", text)
    text = re.sub(r"who's", "who is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"shouldn't", "should not", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"   ", " ", text) # Remove any extra spaces
    return text

# %%
train['clean_text'] = train['text'].apply(clean_text)
test['clean_text'] = test['text'].apply(clean_text)

# %% [markdown]
# - remove any characters other then alphabets
# - convert all dicitonary to lower case(for consistency)
# - lemmatize

# %%
def massage_text(text):
    ## remove anything other then characters and put everything in lowercase
    tweet = re.sub("[^a-zA-Z]", ' ', text)
    tweet = tweet.lower()
    tweet = tweet.split()

    lem = WordNetLemmatizer()
    tweet = [lem.lemmatize(word) for word in tweet
             if word not in set(stopwords.words('english'))]
    tweet = ' '.join(tweet)
    return tweet
    print('--here goes nothing')
    print(text)
    print(tweet)

train['clean_text'] = train['text'].apply(massage_text)
test['clean_text'] = test['text'].apply(massage_text)

# %%
train.iloc[0:10][['text','clean_text']]
# Out:
#                                                    text  \
# 1386  Ted Cruz fires back at Jeb  Bush ÛÏWe lose be...
# 4048  This is the first year the Forest Service spen...
# 3086  lightseraphs pissed at you and could have thei...
# 272        Im gonna fight Taylor as soon as I get there
# 7462  NicolaClements4 IÛªm not sure that covering m...
# 4778  kabwandi Breaking news Unconfirmed I just hear...
# 260   The annihilation of Jeb Christie  Kasich is le...
# 2921                Wtf this mom just drowned her child
# 2162  MayorofLondon pls reduce cyclist deaths with a...
# 4818             DoctorDryadma mass murder here we come
#
#                                              clean_text
# 1386  ted cruz fire back jeb bush lose republican li...
# 4048  first year forest service spent half annual bu...
# 3086      lightseraphs pissed could pikachu electrocute
# 272                      im gonna fight taylor soon get
# 7462  nicolaclements sure covering head wound scab s...
# 4778  kabwandi breaking news unconfirmed heard loud ...
# 260   annihilation jeb christie kasich le hour away ...
# 2921                              wtf mom drowned child
# 2162  mayoroflondon pls reduce cyclist death compuls...
# 4818                     doctordryadma mass murder come

# %% [markdown]
# ## 2-2. Word Tokenization
# - tokenize the clean text column

# %%
train['tokens']=train['clean_text'].apply(lambda x: word_tokenize(x))
test['tokens'] = test['clean_text'].apply(lambda x: word_tokenize(x))

# %%
train.head(5)
# Out:
#              keyword                                               text  \
# 1386    bush%20fires  Ted Cruz fires back at Jeb  Bush ÛÏWe lose be...
# 4048  forest%20fires  This is the first year the Forest Service spen...
# 3086     electrocute  lightseraphs pissed at you and could have thei...
# 272       apocalypse       Im gonna fight Taylor as soon as I get there
# 7462          wounds  NicolaClements4 IÛªm not sure that covering m...
#
#       target                                         clean_text  \
# 1386       0  ted cruz fire back jeb bush lose republican li...
# 4048       1  first year forest service spent half annual bu...
# 3086       0      lightseraphs pissed could pikachu electrocute
# 272        0                     im gonna fight taylor soon get
# 7462       0  nicolaclements sure covering head wound scab s...
#
#                                                  tokens
# 1386  [ted, cruz, fire, back, jeb, bush, lose, repub...
# 4048  [first, year, forest, service, spent, half, an...
# 3086  [lightseraphs, pissed, could, pikachu, electro...
# 272             [im, gon, na, fight, taylor, soon, get]
# 7462  [nicolaclements, sure, covering, head, wound, ...

# %% [markdown]
# ## 2-3. Word2Vec
# - convert our data(words) into vectors

# %%
#first, create a list corpus which we would be using to train word2vec mappings
def fn_pre_process_data(doc):
    for rec in doc:
        yield gensim.utils.simple_preprocess(rec)

corpus = list(fn_pre_process_data(train['clean_text']))
corpus += list(fn_pre_process_data(test['clean_text']))

# %%
#inititate the embedding model, we will come back to the passed arguments later
print('initiated ...')
wv_model = Word2Vec(corpus,vector_size=150,window=3,min_count=2)
#wv_model.build_vocab(corpus)
wv_model.train(corpus,total_examples=len(corpus),epochs=10)
#wv_model.save(data_path + 'word2vec.model')
# Out:
# initiated ...
# (581392, 681810)

# %%
# convert the train and text tokens
def get_word_embeddings(token_list,vector,k=150):
    if len(token_list) < 1:
        return np.zeros(k)
    else:

        vectorized = [vector.wv[word] if word in vector.wv else np.random.rand(k) for word in token_list] 
    
    sum = np.sum(vectorized,axis=0)
    ## return the average
    return sum/len(vectorized)       

def get_embeddings(tokens,vector):
        embeddings = tokens.apply(lambda x: get_word_embeddings(x, wv_model))
        return list(embeddings)

# %%
train_embeddings = get_embeddings(train['tokens'],wv_model)
test_embeddings = get_embeddings(test['tokens'],wv_model)

# %% [markdown]
# # 3. Model
# ## Contents
# - train the model
#     - RidgeClassifierCV
#     - sgd classifier
#     - BernoulliNB
#     - RandomForest
#
# ## Model Description
# --------------
# ### Ensemble
# - Combine the predictions of several base estimators built with a given learning algorithm
#     - in order to improve generalizability / robustness over a single estimator.
# - Boosting of Ensemble types
#
# ### Performance - f1-score

# %% [markdown]
# ## 3-2. Train the model

# %%
MLA = [
    #Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),
    
    #GLM
    linear_model.PassiveAggressiveClassifier(),
    linear_model.RidgeClassifierCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),
    
    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),
    
    #Nearest Neighbor
    neighbors.KNeighborsClassifier(),
    
    #Trees    
    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier(),

    XGBClassifier(),
    CatBoostClassifier()  
    ]

# %% [markdown]
# # Comapring all MLA
# - precision
# - recall
# - accuracy
# - f1-score

# %%
train_embeddings = np.array(train_embeddings)
test_embeddings = np.array(test_embeddings)

# %%
# Comparing all machine learning algorithms
from sklearn.metrics import mean_squared_error,confusion_matrix, precision_score, recall_score, auc,roc_curve

row_index = 0
MLA_columns = []
MLA_compare = pd.DataFrame(columns = MLA_columns)

for alg in MLA:
    predicted = alg.fit(train_embeddings, train['target']).predict(test_embeddings)
    fp, tp, th = roc_curve(test['target'], predicted)

    MLA_name = alg.__class__.__name__
    MLA_compare.loc[row_index,'MLA used'] = MLA_name
    MLA_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(train_embeddings, train['target']), 4)
    MLA_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(test_embeddings, test['target']), 4)
    
    
    recall = recall_score(test['target'], predicted)
    precision = precision_score(test['target'], predicted)
    MLA_compare.loc[row_index, 'Precission'] = precision
    MLA_compare.loc[row_index, 'Recall'] = recall
    MLA_compare.loc[row_index, 'F1-score'] = round((2*precision*recall)/(precision+recall),4)
    MLA_compare.loc[row_index, 'AUC'] = auc(fp, tp)

    row_index+=1
# Out:
# /Users/mac/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:39:22] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Learning rate set to 0.022283
# 0:	learn: 0.6880650	total: 72.6ms	remaining: 1m 12s
# 1:	learn: 0.6829057	total: 90.7ms	remaining: 45.3s
# 2:	learn: 0.6780950	total: 108ms	remaining: 35.8s
# 3:	learn: 0.6732733	total: 123ms	remaining: 30.7s
# 4:	learn: 0.6683880	total: 141ms	remaining: 28s
# 5:	learn: 0.6640175	total: 158ms	remaining: 26.1s
# 6:	learn: 0.6599150	total: 179ms	remaining: 25.4s
# 7:	learn: 0.6560046	total: 198ms	remaining: 24.5s
# 8:	learn: 0.6526400	total: 220ms	remaining: 24.2s
# 9:	learn: 0.6489597	total: 241ms	remaining: 23.8s
# 10:	learn: 0.6461711	total: 258ms	remaining: 23.2s
# 11:	learn: 0.6428210	total: 273ms	remaining: 22.5s
# 12:	learn: 0.6397829	total: 294ms	remaining: 22.3s
# 13:	learn: 0.6369906	total: 309ms	remaining: 21.7s
# 14:	learn: 0.6340990	total: 325ms	remaining: 21.3s
# 15:	learn: 0.6312397	total: 344ms	remaining: 21.1s
# 16:	learn: 0.6282032	total: 363ms	remaining: 21s
# 17:	learn: 0.6256723	total: 379ms	remaining: 20.7s
# 18:	learn: 0.6228066	total: 396ms	remaining: 20.5s
# 19:	learn: 0.6206764	total: 415ms	remaining: 20.4s
# 20:	learn: 0.6184263	total: 434ms	remaining: 20.2s
# 21:	learn: 0.6159244	total: 452ms	remaining: 20.1s
# 22:	learn: 0.6136465	total: 471ms	remaining: 20s
# 23:	learn: 0.6115509	total: 496ms	remaining: 20.2s
# 24:	learn: 0.6095893	total: 512ms	remaining: 20s
# 25:	learn: 0.6076041	total: 529ms	remaining: 19.8s
# 26:	learn: 0.6055869	total: 546ms	remaining: 19.7s
# 27:	learn: 0.6039137	total: 563ms	remaining: 19.5s
# 28:	learn: 0.6021295	total: 579ms	remaining: 19.4s
# 29:	learn: 0.6005525	total: 595ms	remaining: 19.2s
# 30:	learn: 0.5989475	total: 616ms	remaining: 19.2s
# 31:	learn: 0.5972702	total: 633ms	remaining: 19.2s
# 32:	learn: 0.5955779	total: 650ms	remaining: 19s
# 33:	learn: 0.5941453	total: 666ms	remaining: 18.9s
# 34:	learn: 0.5926370	total: 682ms	remaining: 18.8s
# 35:	learn: 0.5913786	total: 698ms	remaining: 18.7s
# 36:	learn: 0.5900846	total: 714ms	remaining: 18.6s
# 37:	learn: 0.5889007	total: 730ms	remaining: 18.5s
# 38:	learn: 0.5875345	total: 747ms	remaining: 18.4s
# 39:	learn: 0.5861182	total: 763ms	remaining: 18.3s
# 40:	learn: 0.5849703	total: 782ms	remaining: 18.3s
# 41:	learn: 0.5836107	total: 800ms	remaining: 18.2s
# 42:	learn: 0.5826088	total: 819ms	remaining: 18.2s
# 43:	learn: 0.5814429	total: 840ms	remaining: 18.3s
# 44:	learn: 0.5802021	total: 859ms	remaining: 18.2s
# 45:	learn: 0.5791690	total: 874ms	remaining: 18.1s
# 46:	learn: 0.5780404	total: 890ms	remaining: 18s
# 47:	learn: 0.5765535	total: 906ms	remaining: 18s
# 48:	learn: 0.5756751	total: 923ms	remaining: 17.9s
# 49:	learn: 0.5744974	total: 938ms	remaining: 17.8s
# 50:	learn: 0.5735618	total: 955ms	remaining: 17.8s
# 51:	learn: 0.5723418	total: 971ms	remaining: 17.7s
# 52:	learn: 0.5712823	total: 988ms	remaining: 17.7s
# 53:	learn: 0.5703251	total: 1s	remaining: 17.6s
# 54:	learn: 0.5695189	total: 1.02s	remaining: 17.6s
# 55:	learn: 0.5686548	total: 1.04s	remaining: 17.6s
# 56:	learn: 0.5678344	total: 1.06s	remaining: 17.5s
# 57:	learn: 0.5669102	total: 1.07s	remaining: 17.5s
# 58:	learn: 0.5659738	total: 1.09s	remaining: 17.4s
# 59:	learn: 0.5652725	total: 1.11s	remaining: 17.3s
# 60:	learn: 0.5644097	total: 1.12s	remaining: 17.3s
# 61:	learn: 0.5636386	total: 1.14s	remaining: 17.2s
# 62:	learn: 0.5628303	total: 1.15s	remaining: 17.1s
# 63:	learn: 0.5621185	total: 1.17s	remaining: 17.1s
# 64:	learn: 0.5613731	total: 1.18s	remaining: 17s
# 65:	learn: 0.5603484	total: 1.19s	remaining: 16.9s
# 66:	learn: 0.5596931	total: 1.21s	remaining: 16.8s
# 67:	learn: 0.5590321	total: 1.23s	remaining: 16.8s
# 68:	learn: 0.5581945	total: 1.24s	remaining: 16.8s
# 69:	learn: 0.5575847	total: 1.26s	remaining: 16.7s
# 70:	learn: 0.5566914	total: 1.27s	remaining: 16.7s
# 71:	learn: 0.5560139	total: 1.29s	remaining: 16.6s
# 72:	learn: 0.5553394	total: 1.31s	remaining: 16.6s
# 73:	learn: 0.5548040	total: 1.32s	remaining: 16.5s
# 74:	learn: 0.5541743	total: 1.34s	remaining: 16.5s
# 75:	learn: 0.5534918	total: 1.35s	remaining: 16.4s
# 76:	learn: 0.5528749	total: 1.37s	remaining: 16.4s
# 77:	learn: 0.5521799	total: 1.39s	remaining: 16.4s
# 78:	learn: 0.5515517	total: 1.4s	remaining: 16.4s
# 79:	learn: 0.5508538	total: 1.42s	remaining: 16.3s
# 80:	learn: 0.5501984	total: 1.44s	remaining: 16.4s
# 81:	learn: 0.5494205	total: 1.46s	remaining: 16.3s
# 82:	learn: 0.5488698	total: 1.48s	remaining: 16.3s
# 83:	learn: 0.5482167	total: 1.49s	remaining: 16.3s
# 84:	learn: 0.5477940	total: 1.51s	remaining: 16.3s
# 85:	learn: 0.5473382	total: 1.52s	remaining: 16.2s
# 86:	learn: 0.5466858	total: 1.54s	remaining: 16.2s
# 87:	learn: 0.5461917	total: 1.56s	remaining: 16.2s
# 88:	learn: 0.5456536	total: 1.58s	remaining: 16.1s
# 89:	learn: 0.5450462	total: 1.59s	remaining: 16.1s
# 90:	learn: 0.5444049	total: 1.61s	remaining: 16.1s
# 91:	learn: 0.5438190	total: 1.63s	remaining: 16s
# 92:	learn: 0.5433200	total: 1.64s	remaining: 16s
# 93:	learn: 0.5427070	total: 1.66s	remaining: 16s
# 94:	learn: 0.5421595	total: 1.68s	remaining: 16s
# 95:	learn: 0.5417898	total: 1.69s	remaining: 15.9s
# 96:	learn: 0.5412163	total: 1.71s	remaining: 15.9s
# 97:	learn: 0.5406176	total: 1.72s	remaining: 15.9s
# 98:	learn: 0.5399971	total: 1.74s	remaining: 15.8s
# 99:	learn: 0.5394832	total: 1.75s	remaining: 15.8s
# 100:	learn: 0.5388025	total: 1.77s	remaining: 15.8s
# 101:	learn: 0.5382015	total: 1.78s	remaining: 15.7s
# 102:	learn: 0.5376425	total: 1.8s	remaining: 15.7s
# 103:	learn: 0.5373337	total: 1.82s	remaining: 15.7s
# 104:	learn: 0.5368776	total: 1.84s	remaining: 15.7s
# 105:	learn: 0.5364321	total: 1.85s	remaining: 15.6s
# 106:	learn: 0.5360099	total: 1.87s	remaining: 15.6s
# 107:	learn: 0.5355793	total: 1.89s	remaining: 15.6s
# 108:	learn: 0.5351672	total: 1.9s	remaining: 15.5s
# 109:	learn: 0.5347408	total: 1.92s	remaining: 15.5s
# 110:	learn: 0.5344206	total: 1.93s	remaining: 15.5s
# 111:	learn: 0.5340341	total: 1.95s	remaining: 15.4s
# 112:	learn: 0.5336156	total: 1.96s	remaining: 15.4s
# 113:	learn: 0.5331260	total: 1.98s	remaining: 15.4s
# 114:	learn: 0.5325023	total: 1.99s	remaining: 15.3s
# 115:	learn: 0.5321364	total: 2.01s	remaining: 15.3s
# 116:	learn: 0.5315080	total: 2.02s	remaining: 15.3s
# 117:	learn: 0.5311186	total: 2.04s	remaining: 15.2s
# 118:	learn: 0.5307614	total: 2.06s	remaining: 15.2s
# 119:	learn: 0.5303251	total: 2.08s	remaining: 15.2s
# 120:	learn: 0.5299867	total: 2.09s	remaining: 15.2s
# 121:	learn: 0.5294986	total: 2.11s	remaining: 15.2s
# 122:	learn: 0.5290604	total: 2.12s	remaining: 15.1s
# 123:	learn: 0.5285905	total: 2.14s	remaining: 15.1s
# 124:	learn: 0.5281431	total: 2.16s	remaining: 15.1s
# 125:	learn: 0.5276451	total: 2.17s	remaining: 15.1s
# 126:	learn: 0.5271896	total: 2.19s	remaining: 15.1s
# 127:	learn: 0.5267877	total: 2.21s	remaining: 15s
# 128:	learn: 0.5264643	total: 2.22s	remaining: 15s
# 129:	learn: 0.5260679	total: 2.24s	remaining: 15s
# 130:	learn: 0.5256987	total: 2.26s	remaining: 15s
# 131:	learn: 0.5252045	total: 2.28s	remaining: 15s
# 132:	learn: 0.5248269	total: 2.3s	remaining: 15s
# 133:	learn: 0.5244185	total: 2.31s	remaining: 15s
# 134:	learn: 0.5240420	total: 2.33s	remaining: 15s
# 135:	learn: 0.5234827	total: 2.35s	remaining: 14.9s
# 136:	learn: 0.5230877	total: 2.37s	remaining: 14.9s
# 137:	learn: 0.5226663	total: 2.38s	remaining: 14.9s
# 138:	learn: 0.5222155	total: 2.4s	remaining: 14.9s
# 139:	learn: 0.5217722	total: 2.42s	remaining: 14.8s
# 140:	learn: 0.5213618	total: 2.44s	remaining: 14.8s
# 141:	learn: 0.5208493	total: 2.45s	remaining: 14.8s
# 142:	learn: 0.5203808	total: 2.47s	remaining: 14.8s
# 143:	learn: 0.5200646	total: 2.49s	remaining: 14.8s
# 144:	learn: 0.5197246	total: 2.51s	remaining: 14.8s
# 145:	learn: 0.5194628	total: 2.52s	remaining: 14.8s
# 146:	learn: 0.5190374	total: 2.54s	remaining: 14.7s
# 147:	learn: 0.5186985	total: 2.56s	remaining: 14.7s
# 333:	learn: 0.4637719	total: 5.44s	remaining: 10.9s
# 334:	learn: 0.4634910	total: 5.45s	remaining: 10.8s
# 335:	learn: 0.4631479	total: 5.47s	remaining: 10.8s
# 336:	learn: 0.4627591	total: 5.48s	remaining: 10.8s
# 337:	learn: 0.4625634	total: 5.5s	remaining: 10.8s
# 338:	learn: 0.4622835	total: 5.52s	remaining: 10.8s
# 339:	learn: 0.4620502	total: 5.53s	remaining: 10.7s
# 340:	learn: 0.4618028	total: 5.55s	remaining: 10.7s
# 341:	learn: 0.4615575	total: 5.56s	remaining: 10.7s
# 342:	learn: 0.4612874	total: 5.58s	remaining: 10.7s
# 343:	learn: 0.4609097	total: 5.6s	remaining: 10.7s
# 344:	learn: 0.4606630	total: 5.63s	remaining: 10.7s
# 345:	learn: 0.4604212	total: 5.65s	remaining: 10.7s
# 346:	learn: 0.4601889	total: 5.66s	remaining: 10.7s
# 347:	learn: 0.4599446	total: 5.68s	remaining: 10.6s
# 348:	learn: 0.4595910	total: 5.7s	remaining: 10.6s
# 349:	learn: 0.4593860	total: 5.71s	remaining: 10.6s
# 350:	learn: 0.4590010	total: 5.73s	remaining: 10.6s
# 351:	learn: 0.4586753	total: 5.74s	remaining: 10.6s
# 352:	learn: 0.4583110	total: 5.76s	remaining: 10.6s
# 353:	learn: 0.4580741	total: 5.78s	remaining: 10.5s
# 354:	learn: 0.4578976	total: 5.79s	remaining: 10.5s
# 355:	learn: 0.4576044	total: 5.8s	remaining: 10.5s
# 356:	learn: 0.4574666	total: 5.82s	remaining: 10.5s
# 357:	learn: 0.4572816	total: 5.83s	remaining: 10.5s
# 358:	learn: 0.4570071	total: 5.85s	remaining: 10.4s
# 359:	learn: 0.4567102	total: 5.86s	remaining: 10.4s
# 360:	learn: 0.4565037	total: 5.88s	remaining: 10.4s
# 361:	learn: 0.4562776	total: 5.89s	remaining: 10.4s
# 362:	learn: 0.4560552	total: 5.91s	remaining: 10.4s
# 363:	learn: 0.4557744	total: 5.92s	remaining: 10.3s
# 364:	learn: 0.4554558	total: 5.94s	remaining: 10.3s
# 365:	learn: 0.4550766	total: 5.95s	remaining: 10.3s
# 366:	learn: 0.4547477	total: 5.97s	remaining: 10.3s
# 367:	learn: 0.4544397	total: 5.99s	remaining: 10.3s
# 368:	learn: 0.4541837	total: 6.01s	remaining: 10.3s
# 369:	learn: 0.4538541	total: 6.02s	remaining: 10.3s
# 370:	learn: 0.4535545	total: 6.04s	remaining: 10.2s
# 371:	learn: 0.4531756	total: 6.05s	remaining: 10.2s
# 372:	learn: 0.4529559	total: 6.07s	remaining: 10.2s
# 373:	learn: 0.4526772	total: 6.08s	remaining: 10.2s
# 374:	learn: 0.4524057	total: 6.09s	remaining: 10.2s
# 375:	learn: 0.4521033	total: 6.11s	remaining: 10.1s
# 376:	learn: 0.4518112	total: 6.13s	remaining: 10.1s
# 377:	learn: 0.4516790	total: 6.14s	remaining: 10.1s
# 378:	learn: 0.4514281	total: 6.16s	remaining: 10.1s
# 609:	learn: 0.3904611	total: 9.71s	remaining: 6.21s
# 610:	learn: 0.3902612	total: 9.72s	remaining: 6.19s
# 611:	learn: 0.3900073	total: 9.74s	remaining: 6.17s
# 612:	learn: 0.3896693	total: 9.75s	remaining: 6.16s
# 613:	learn: 0.3894197	total: 9.77s	remaining: 6.14s
# 614:	learn: 0.3891871	total: 9.78s	remaining: 6.12s
# 615:	learn: 0.3889216	total: 9.79s	remaining: 6.11s
# 616:	learn: 0.3886779	total: 9.81s	remaining: 6.09s
# 617:	learn: 0.3884507	total: 9.83s	remaining: 6.08s
# 618:	learn: 0.3882631	total: 9.84s	remaining: 6.06s
# 619:	learn: 0.3880010	total: 9.86s	remaining: 6.04s
# 620:	learn: 0.3876404	total: 9.88s	remaining: 6.03s
# 621:	learn: 0.3873208	total: 9.89s	remaining: 6.01s
# 622:	learn: 0.3871410	total: 9.9s	remaining: 5.99s
# 623:	learn: 0.3869153	total: 9.92s	remaining: 5.98s
# 624:	learn: 0.3865766	total: 9.94s	remaining: 5.96s
# 625:	learn: 0.3863870	total: 9.95s	remaining: 5.95s
# 626:	learn: 0.3860577	total: 9.96s	remaining: 5.93s
# 627:	learn: 0.3857533	total: 9.98s	remaining: 5.91s
# 628:	learn: 0.3856239	total: 9.99s	remaining: 5.89s
# 629:	learn: 0.3853658	total: 10s	remaining: 5.88s
# 630:	learn: 0.3851382	total: 10s	remaining: 5.86s
# 631:	learn: 0.3849011	total: 10s	remaining: 5.84s
# 632:	learn: 0.3845624	total: 10.1s	remaining: 5.83s
# 633:	learn: 0.3841805	total: 10.1s	remaining: 5.81s
# 634:	learn: 0.3840118	total: 10.1s	remaining: 5.8s
# 635:	learn: 0.3837591	total: 10.1s	remaining: 5.78s
# 636:	learn: 0.3835709	total: 10.1s	remaining: 5.77s
# 637:	learn: 0.3832934	total: 10.1s	remaining: 5.75s
# 638:	learn: 0.3829316	total: 10.1s	remaining: 5.73s
# 639:	learn: 0.3826138	total: 10.2s	remaining: 5.72s
# 640:	learn: 0.3823299	total: 10.2s	remaining: 5.7s
# 641:	learn: 0.3820786	total: 10.2s	remaining: 5.68s
# 642:	learn: 0.3818015	total: 10.2s	remaining: 5.67s
# 643:	learn: 0.3814233	total: 10.2s	remaining: 5.65s
# 644:	learn: 0.3812622	total: 10.2s	remaining: 5.63s
# 645:	learn: 0.3809977	total: 10.3s	remaining: 5.62s
# 646:	learn: 0.3807657	total: 10.3s	remaining: 5.6s
# 647:	learn: 0.3805016	total: 10.3s	remaining: 5.59s
# 648:	learn: 0.3801639	total: 10.3s	remaining: 5.57s
# 649:	learn: 0.3798997	total: 10.3s	remaining: 5.55s
# 650:	learn: 0.3796777	total: 10.3s	remaining: 5.54s
# 651:	learn: 0.3793941	total: 10.3s	remaining: 5.52s
# 652:	learn: 0.3792298	total: 10.4s	remaining: 5.51s
# 653:	learn: 0.3789709	total: 10.4s	remaining: 5.49s
# 654:	learn: 0.3788113	total: 10.4s	remaining: 5.47s
# 655:	learn: 0.3785759	total: 10.4s	remaining: 5.46s
# 656:	learn: 0.3782672	total: 10.4s	remaining: 5.44s
# 657:	learn: 0.3780535	total: 10.4s	remaining: 5.43s
# 658:	learn: 0.3778234	total: 10.5s	remaining: 5.41s
# 659:	learn: 0.3775064	total: 10.5s	remaining: 5.4s
# 660:	learn: 0.3773217	total: 10.5s	remaining: 5.38s
# 661:	learn: 0.3771854	total: 10.5s	remaining: 5.36s
# 662:	learn: 0.3769709	total: 10.5s	remaining: 5.35s
# 663:	learn: 0.3767061	total: 10.5s	remaining: 5.33s
# 664:	learn: 0.3765717	total: 10.5s	remaining: 5.31s
# 665:	learn: 0.3764364	total: 10.6s	remaining: 5.3s
# 666:	learn: 0.3763026	total: 10.6s	remaining: 5.28s
# 667:	learn: 0.3761842	total: 10.6s	remaining: 5.26s
# 668:	learn: 0.3758263	total: 10.6s	remaining: 5.25s
# 669:	learn: 0.3754936	total: 10.6s	remaining: 5.23s
# 670:	learn: 0.3752223	total: 10.6s	remaining: 5.22s
# 671:	learn: 0.3749206	total: 10.7s	remaining: 5.2s
# 672:	learn: 0.3746929	total: 10.7s	remaining: 5.18s
# 673:	learn: 0.3745622	total: 10.7s	remaining: 5.17s
# 674:	learn: 0.3743778	total: 10.7s	remaining: 5.15s
# 675:	learn: 0.3740827	total: 10.7s	remaining: 5.14s
# 676:	learn: 0.3738015	total: 10.7s	remaining: 5.12s
# 677:	learn: 0.3736759	total: 10.8s	remaining: 5.11s
# 678:	learn: 0.3735320	total: 10.8s	remaining: 5.09s
# 679:	learn: 0.3733749	total: 10.8s	remaining: 5.07s
# 680:	learn: 0.3731829	total: 10.8s	remaining: 5.06s
# 681:	learn: 0.3728518	total: 10.8s	remaining: 5.04s
# 682:	learn: 0.3725071	total: 10.8s	remaining: 5.02s
# 683:	learn: 0.3721993	total: 10.8s	remaining: 5.01s
# 684:	learn: 0.3719579	total: 10.9s	remaining: 4.99s
# 685:	learn: 0.3716639	total: 10.9s	remaining: 4.98s
# 686:	learn: 0.3714832	total: 10.9s	remaining: 4.96s
# 687:	learn: 0.3711062	total: 10.9s	remaining: 4.95s
# 688:	learn: 0.3707739	total: 10.9s	remaining: 4.93s
# 689:	learn: 0.3705396	total: 10.9s	remaining: 4.91s
# 690:	learn: 0.3702272	total: 10.9s	remaining: 4.89s
# 691:	learn: 0.3698634	total: 11s	remaining: 4.88s
# 692:	learn: 0.3696808	total: 11s	remaining: 4.86s
# 693:	learn: 0.3694415	total: 11s	remaining: 4.85s
# 694:	learn: 0.3692655	total: 11s	remaining: 4.83s
# 695:	learn: 0.3690882	total: 11s	remaining: 4.82s
# 696:	learn: 0.3688370	total: 11s	remaining: 4.8s
# 697:	learn: 0.3686574	total: 11.1s	remaining: 4.78s
# 698:	learn: 0.3685646	total: 11.1s	remaining: 4.77s
# 699:	learn: 0.3682678	total: 11.1s	remaining: 4.75s
# 700:	learn: 0.3680398	total: 11.1s	remaining: 4.74s
# 701:	learn: 0.3677944	total: 11.1s	remaining: 4.72s
# 748:	learn: 0.3563465	total: 11.8s	remaining: 3.97s
# 749:	learn: 0.3561097	total: 11.9s	remaining: 3.95s
# 750:	learn: 0.3559480	total: 11.9s	remaining: 3.94s
# 751:	learn: 0.3557462	total: 11.9s	remaining: 3.92s
# 752:	learn: 0.3555098	total: 11.9s	remaining: 3.91s
# 753:	learn: 0.3553507	total: 11.9s	remaining: 3.89s
# 754:	learn: 0.3552196	total: 11.9s	remaining: 3.88s
# 755:	learn: 0.3549887	total: 12s	remaining: 3.86s
# 756:	learn: 0.3547058	total: 12s	remaining: 3.84s
# 757:	learn: 0.3544840	total: 12s	remaining: 3.83s
# 758:	learn: 0.3541063	total: 12s	remaining: 3.81s
# 759:	learn: 0.3538421	total: 12s	remaining: 3.79s
# 760:	learn: 0.3536050	total: 12s	remaining: 3.78s
# 761:	learn: 0.3534982	total: 12s	remaining: 3.76s
# 762:	learn: 0.3532335	total: 12.1s	remaining: 3.75s
# 763:	learn: 0.3529691	total: 12.1s	remaining: 3.73s
# 764:	learn: 0.3526700	total: 12.1s	remaining: 3.72s
# 765:	learn: 0.3523305	total: 12.1s	remaining: 3.7s
# 766:	learn: 0.3521167	total: 12.1s	remaining: 3.68s
# 767:	learn: 0.3521068	total: 12.1s	remaining: 3.67s
# 768:	learn: 0.3518497	total: 12.2s	remaining: 3.65s
# 769:	learn: 0.3515206	total: 12.2s	remaining: 3.64s
# 770:	learn: 0.3512779	total: 12.2s	remaining: 3.62s
# 771:	learn: 0.3509573	total: 12.2s	remaining: 3.6s
# 772:	learn: 0.3508124	total: 12.2s	remaining: 3.59s
# 773:	learn: 0.3505284	total: 12.2s	remaining: 3.57s
# 774:	learn: 0.3502179	total: 12.3s	remaining: 3.56s
# 775:	learn: 0.3500374	total: 12.3s	remaining: 3.54s
# 776:	learn: 0.3497529	total: 12.3s	remaining: 3.52s
# 777:	learn: 0.3494767	total: 12.3s	remaining: 3.51s
# 778:	learn: 0.3493166	total: 12.3s	remaining: 3.5s
# 779:	learn: 0.3491553	total: 12.3s	remaining: 3.48s
# 780:	learn: 0.3489933	total: 12.4s	remaining: 3.46s
# 781:	learn: 0.3488261	total: 12.4s	remaining: 3.45s
# 782:	learn: 0.3486249	total: 12.4s	remaining: 3.43s
# 783:	learn: 0.3483126	total: 12.4s	remaining: 3.42s
# 784:	learn: 0.3480289	total: 12.4s	remaining: 3.4s
# 785:	learn: 0.3478485	total: 12.4s	remaining: 3.38s
# 786:	learn: 0.3475457	total: 12.4s	remaining: 3.37s
# 787:	learn: 0.3473485	total: 12.5s	remaining: 3.35s
# 788:	learn: 0.3470659	total: 12.5s	remaining: 3.34s
# 789:	learn: 0.3467930	total: 12.5s	remaining: 3.32s
# 790:	learn: 0.3464446	total: 12.5s	remaining: 3.31s
# 791:	learn: 0.3462003	total: 12.5s	remaining: 3.29s
# 792:	learn: 0.3459542	total: 12.5s	remaining: 3.27s
# 793:	learn: 0.3457700	total: 12.6s	remaining: 3.26s
# 794:	learn: 0.3454520	total: 12.6s	remaining: 3.24s
# 795:	learn: 0.3452501	total: 12.6s	remaining: 3.23s
# 796:	learn: 0.3450374	total: 12.6s	remaining: 3.21s
# 797:	learn: 0.3447809	total: 12.6s	remaining: 3.19s
# 798:	learn: 0.3445804	total: 12.6s	remaining: 3.18s
# 799:	learn: 0.3444184	total: 12.7s	remaining: 3.16s
# 800:	learn: 0.3441679	total: 12.7s	remaining: 3.15s
# 801:	learn: 0.3439971	total: 12.7s	remaining: 3.13s
# 802:	learn: 0.3437994	total: 12.7s	remaining: 3.12s
# 803:	learn: 0.3436052	total: 12.7s	remaining: 3.1s
# 804:	learn: 0.3433207	total: 12.7s	remaining: 3.08s
# 805:	learn: 0.3430257	total: 12.7s	remaining: 3.07s
# 806:	learn: 0.3427411	total: 12.8s	remaining: 3.05s
# 807:	learn: 0.3425408	total: 12.8s	remaining: 3.04s
# 808:	learn: 0.3423378	total: 12.8s	remaining: 3.02s
# 809:	learn: 0.3421405	total: 12.8s	remaining: 3s
# 810:	learn: 0.3421332	total: 12.8s	remaining: 2.99s
# 811:	learn: 0.3418551	total: 12.8s	remaining: 2.97s
# 812:	learn: 0.3417753	total: 12.9s	remaining: 2.96s
# 813:	learn: 0.3414726	total: 12.9s	remaining: 2.94s
# 814:	learn: 0.3413266	total: 12.9s	remaining: 2.92s
# 815:	learn: 0.3410873	total: 12.9s	remaining: 2.91s
# 816:	learn: 0.3408762	total: 12.9s	remaining: 2.89s
# 817:	learn: 0.3405795	total: 12.9s	remaining: 2.88s
# 818:	learn: 0.3403380	total: 12.9s	remaining: 2.86s
# 819:	learn: 0.3400836	total: 13s	remaining: 2.85s
# 820:	learn: 0.3399174	total: 13s	remaining: 2.83s
# 821:	learn: 0.3396845	total: 13s	remaining: 2.81s
# 822:	learn: 0.3393590	total: 13s	remaining: 2.8s
# 823:	learn: 0.3391378	total: 13s	remaining: 2.78s
# 824:	learn: 0.3389168	total: 13s	remaining: 2.77s
# 825:	learn: 0.3388265	total: 13.1s	remaining: 2.75s
# 826:	learn: 0.3384854	total: 13.1s	remaining: 2.73s
# 827:	learn: 0.3382594	total: 13.1s	remaining: 2.72s
# 828:	learn: 0.3379530	total: 13.1s	remaining: 2.71s
# 829:	learn: 0.3378054	total: 13.1s	remaining: 2.69s
# 830:	learn: 0.3376814	total: 13.2s	remaining: 2.67s
# 831:	learn: 0.3375159	total: 13.2s	remaining: 2.66s
# 832:	learn: 0.3371831	total: 13.2s	remaining: 2.64s
# 833:	learn: 0.3369113	total: 13.2s	remaining: 2.63s
# 834:	learn: 0.3367074	total: 13.2s	remaining: 2.61s
# 835:	learn: 0.3364482	total: 13.2s	remaining: 2.6s
# 836:	learn: 0.3362540	total: 13.3s	remaining: 2.58s
# 837:	learn: 0.3362415	total: 13.3s	remaining: 2.56s
# 838:	learn: 0.3360191	total: 13.3s	remaining: 2.55s
# 839:	learn: 0.3357390	total: 13.3s	remaining: 2.53s
# 840:	learn: 0.3354793	total: 13.3s	remaining: 2.52s
# 887:	learn: 0.3254990	total: 14.1s	remaining: 1.78s
# 888:	learn: 0.3252410	total: 14.1s	remaining: 1.76s
# 889:	learn: 0.3250101	total: 14.1s	remaining: 1.75s
# 890:	learn: 0.3247501	total: 14.1s	remaining: 1.73s
# 891:	learn: 0.3244529	total: 14.2s	remaining: 1.72s
# 892:	learn: 0.3242915	total: 14.2s	remaining: 1.7s
# 893:	learn: 0.3240747	total: 14.2s	remaining: 1.68s
# 894:	learn: 0.3238337	total: 14.2s	remaining: 1.67s
# 895:	learn: 0.3237405	total: 14.2s	remaining: 1.65s
# 896:	learn: 0.3236054	total: 14.2s	remaining: 1.64s
# 897:	learn: 0.3234271	total: 14.3s	remaining: 1.62s
# 898:	learn: 0.3233174	total: 14.3s	remaining: 1.6s
# 899:	learn: 0.3230719	total: 14.3s	remaining: 1.59s
# 900:	learn: 0.3228422	total: 14.3s	remaining: 1.57s
# 901:	learn: 0.3226355	total: 14.3s	remaining: 1.56s
# 902:	learn: 0.3226278	total: 14.3s	remaining: 1.54s
# 903:	learn: 0.3223856	total: 14.4s	remaining: 1.52s
# 904:	learn: 0.3222205	total: 14.4s	remaining: 1.51s
# 905:	learn: 0.3220958	total: 14.4s	remaining: 1.49s
# 906:	learn: 0.3218722	total: 14.4s	remaining: 1.48s
# 907:	learn: 0.3216994	total: 14.4s	remaining: 1.46s
# 908:	learn: 0.3215617	total: 14.4s	remaining: 1.45s
# 909:	learn: 0.3213174	total: 14.5s	remaining: 1.43s
# 910:	learn: 0.3210863	total: 14.5s	remaining: 1.41s
# 911:	learn: 0.3208292	total: 14.5s	remaining: 1.4s
# 912:	learn: 0.3206606	total: 14.5s	remaining: 1.38s
# 913:	learn: 0.3203945	total: 14.5s	remaining: 1.37s
# 914:	learn: 0.3200972	total: 14.5s	remaining: 1.35s
# 915:	learn: 0.3198195	total: 14.6s	remaining: 1.33s
# 916:	learn: 0.3195533	total: 14.6s	remaining: 1.32s
# 917:	learn: 0.3193919	total: 14.6s	remaining: 1.3s
# 918:	learn: 0.3192042	total: 14.6s	remaining: 1.29s
# 919:	learn: 0.3190262	total: 14.6s	remaining: 1.27s
# 920:	learn: 0.3187675	total: 14.6s	remaining: 1.25s
# 921:	learn: 0.3185260	total: 14.7s	remaining: 1.24s
# 922:	learn: 0.3183130	total: 14.7s	remaining: 1.22s
# 923:	learn: 0.3182231	total: 14.7s	remaining: 1.21s
# 924:	learn: 0.3181670	total: 14.7s	remaining: 1.19s
# 925:	learn: 0.3179270	total: 14.7s	remaining: 1.18s
# 926:	learn: 0.3177320	total: 14.7s	remaining: 1.16s
# 927:	learn: 0.3176020	total: 14.8s	remaining: 1.14s
# 928:	learn: 0.3174678	total: 14.8s	remaining: 1.13s
# 929:	learn: 0.3172619	total: 14.8s	remaining: 1.11s
# 930:	learn: 0.3171948	total: 14.8s	remaining: 1.1s
# 931:	learn: 0.3169411	total: 14.8s	remaining: 1.08s
# 932:	learn: 0.3166505	total: 14.8s	remaining: 1.06s
# 981:	learn: 0.3079167	total: 15.6s	remaining: 286ms
# 982:	learn: 0.3077232	total: 15.6s	remaining: 270ms
# 983:	learn: 0.3076333	total: 15.6s	remaining: 254ms
# 984:	learn: 0.3074546	total: 15.6s	remaining: 238ms
# 985:	learn: 0.3072186	total: 15.7s	remaining: 222ms
# 986:	learn: 0.3069902	total: 15.7s	remaining: 207ms
# 987:	learn: 0.3068082	total: 15.7s	remaining: 191ms
# 988:	learn: 0.3066087	total: 15.7s	remaining: 175ms
# 989:	learn: 0.3063774	total: 15.7s	remaining: 159ms
# 990:	learn: 0.3062918	total: 15.7s	remaining: 143ms
# 991:	learn: 0.3061976	total: 15.8s	remaining: 127ms
# 992:	learn: 0.3060834	total: 15.8s	remaining: 111ms
# 993:	learn: 0.3060779	total: 15.8s	remaining: 95.3ms
# 994:	learn: 0.3059510	total: 15.8s	remaining: 79.4ms
# 995:	learn: 0.3057689	total: 15.8s	remaining: 63.5ms
# 996:	learn: 0.3055911	total: 15.8s	remaining: 47.7ms
# 997:	learn: 0.3054220	total: 15.9s	remaining: 31.8ms
# 998:	learn: 0.3052103	total: 15.9s	remaining: 15.9ms
# 999:	learn: 0.3049997	total: 15.9s	remaining: 0us

# %%
# f1-score 기준 정렬
MLA_compare.sort_values(by = ['F1-score'], ascending = False, inplace = True)    
MLA_compare
# Out:
#                        MLA used  Train Accuracy  Test Accuracy  Precission  \
# 8                    Perceptron          0.6938         0.7039    0.648089
# 15           CatBoostClassifier          0.9227         0.7347    0.754923
# 14                XGBClassifier          0.9890         0.7216    0.712575
# 4        RandomForestClassifier          0.9890         0.7347    0.766590
# 2          ExtraTreesClassifier          0.9890         0.7400    0.796069
# 3    GradientBoostingClassifier          0.7910         0.7295    0.755102
# 6             RidgeClassifierCV          0.7220         0.7295    0.775061
# 7                 SGDClassifier          0.7197         0.7137    0.718004
# 0            AdaBoostClassifier          0.7368         0.7019    0.692632
# 11         KNeighborsClassifier          0.7944         0.6763    0.629032
# 9                   BernoulliNB          0.5901         0.6074    0.524164
# 1             BaggingClassifier          0.9745         0.6881    0.668050
# 12       DecisionTreeClassifier          0.9890         0.6481    0.581059
# 13          ExtraTreeClassifier          0.9890         0.6336    0.560122
# 10                   GaussianNB          0.6105         0.6192    0.542601
# 5   PassiveAggressiveClassifier          0.6136         0.6211    0.875000
#
#       Recall  F1-score       AUC
# 8   0.638932    0.6435  0.694748
# 15  0.541601    0.6307  0.707595
# 14  0.560440    0.6274  0.698956
# 4   0.525903    0.6238  0.705389
# 2   0.508634    0.6207  0.707477
# 3   0.522763    0.6178  0.700433
# 6   0.497645    0.6061  0.696904
# 7   0.519623    0.6029  0.686448
# 0   0.516484    0.5917  0.675849
# 11  0.551020    0.5874  0.658693
# 9   0.664050    0.5859  0.615321
# 1   0.505495    0.5755  0.662454
# 12  0.568289    0.5746  0.636853
# 13  0.577708    0.5688  0.625761
# 10  0.569859    0.5559  0.612243
# 5   0.109890    0.1953  0.549302
