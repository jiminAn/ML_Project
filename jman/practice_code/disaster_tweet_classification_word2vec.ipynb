# %% [markdown]
# # Disaster Tweet Classification wi
# ## NLP with Disaster Tweets
# ------------------
# ### GOAL
# - Predicting whether a given tweet is about a real disaster or not
# - if so, predict a `1`. if not, predict a `0`
#
#
# ### Reference
# - [competition main page](https://www.kaggle.com/c/nlp-getting-started)
# - [word2vec code](https://www.kaggle.com/slatawa/simple-implementation-of-word2vec)
# - [example code](https://www.kaggle.com/datarohitingole/disaster-tweet-classification-ridgeclassifiercv)
# - [comparing the performance of different Machine Learning Algorithm](https://dibyendudeb.com/comparing-machine-learning-algorithms/)

# %% [markdown]
# # 0. Importing Libraries

# %%
# for loading and preprocessing the data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re

# for training the model
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import tree, linear_model, neighbors, naive_bayes, ensemble
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# for evaluating classification model
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

# for data cleaning
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('punkt')

# for word2vec
import gensim
from gensim.models import Word2Vec

# Comparing all machine learning algorithms
from sklearn.metrics import mean_squared_error,confusion_matrix, precision_score, recall_score, auc,roc_curve
# Out:
# [nltk_data] Downloading package wordnet to /Users/mac/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/mac/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # 2. Data Preprocessing
# ## Contents
# #### 1. Clean the data
# - dealing with missing values
# - replace some commonly occuring shorthands
# - remove any characters other then alphabets
# - convert all dicitonary to lower case(for consistency)
# - lemmatize
#
# #### 2. word toeknization
#
# #### 3. Word2Vector

# %% [markdown]
# ## Data Description
# --------------
# ### Files
# - `train.csv` : the training set
# - `test.csv` : the test set
# - `sample_submission.csv` : a sample submission file in the correct format
#
# ### Columns
# - `id` : a unique identifier for each tweet
# - `text` : the text of the tweet
# - `location` : the location the tweet was sent from
# - `keyword` : a particular keyword from th tweet
# - `target` : in train.csv only, this denotes whether a tweet is about a real disaster(1) or not(0)

# %%
# loading the data set
data_path = './data/'
train = pd.read_csv(data_path + 'train.csv')
#test = pd.read_csv(data_path + 'test.csv')

#all_data = [train,test]

# %%
# split the data <train : test = 8 : 2>
train, test = train_test_split(train, test_size = 0.20, random_state = 0)

# %%
print('train_shape:', train.shape)
print('test_shape;', test.shape)
# Out:
# train_shape: (6090, 5)
# test_shape; (1523, 5)

# %%
train.head()
# Out:
#          id         keyword   location  \
# 1386   1999    bush%20fires        NaN
# 4048   5751  forest%20fires        NaN
# 3086   4428     electrocute        NaN
# 272     396      apocalypse   ColoRADo
# 7462  10678          wounds  Tampa, FL
#
#                                                    text  target
# 1386  Ted Cruz fires back at Jeb &amp; Bush: ÛÏWe l...       0
# 4048  This is the first year the Forest Service spen...       1
# 3086  @lightseraphs pissed at you and could have the...       0
# 272      I'm gonna fight Taylor as soon as I get there.       0
# 7462  @NicolaClements4 IÛªm not sure that covering ...       0

# %%
test.head()
# Out:
#         id         keyword                   location  \
# 311    454      armageddon              Wrigley Field
# 4970  7086        meltdown            Two Up Two Down
# 527    762       avalanche  Score Team Goals Buying @
# 6362  9094  suicide%20bomb                   Roadside
# 800   1160          blight        Laventillemoorings
#
#                                                    text  target
# 311   @KatieKatCubs you already know how this shit g...       0
# 4970  @LeMaireLee @danharmon People Near Meltdown Co...       0
# 527   1-6 TIX Calgary Flames vs COL Avalanche Presea...       0
# 6362  If you ever think you running out of choices i...       0
# 800   If you dotish to blight your car go right ahea...       0

# %% [markdown]
# ## 2-1. Clean the data
# - Dealing with Missing Values

# %%
all_data = [train,test]
for data in all_data:
    data.drop(["location", "id"], axis = 1, inplace = True)

# %%
# data prepocessing with regrex

def remove_URL(text): # remove url pattern in text
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)

def remove_html(text): # remove html pattern in text
    html = re.compile(r'<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    return html.sub(r'', text)
    #return re.sub(html, '', text)

def remove_punct(text): # remove punctuation in text: (;, ', ", :, ., , etc..)
  table = str.maketrans('', '', string.punctuation)
  return text.translate(table)

# %%
for data in all_data:
  data['text'] = data['text'].apply(lambda x: remove_URL(x))
  data['text'] = data['text'].apply(lambda x: remove_html(x))
  data['text'] = data['text'].apply(lambda x: remove_punct(x))

# %% [markdown]
# - Replace some commonly occuring shorthands

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"you'll", "you will", text)
    text = re.sub(r"i'll", "i will", text)
    text = re.sub(r"she'll", "she will", text)
    text = re.sub(r"he'll", "he will", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"there's", "there is", text)
    text = re.sub(r"here's", "here is", text)
    text = re.sub(r"who's", "who is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"shouldn't", "should not", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"   ", " ", text) # Remove any extra spaces
    return text

# %%
train['clean_text'] = train['text'].apply(clean_text)
test['clean_text'] = test['text'].apply(clean_text)

# %% [markdown]
# - remove any characters other then alphabets
# - convert all dicitonary to lower case(for consistency)
# - lemmatize

# %%
def massage_text(text):
    ## remove anything other then characters and put everything in lowercase
    tweet = re.sub("[^a-zA-Z]", ' ', text)
    tweet = tweet.lower()
    tweet = tweet.split()

    lem = WordNetLemmatizer()
    tweet = [lem.lemmatize(word) for word in tweet
             if word not in set(stopwords.words('english'))]
    tweet = ' '.join(tweet)
    return tweet
    print('--here goes nothing')
    print(text)
    print(tweet)

train['clean_text'] = train['text'].apply(massage_text)
test['clean_text'] = test['text'].apply(massage_text)

# %%
train.iloc[0:10][['text','clean_text']]
# Out:
#                                                    text  \
# 1386  Ted Cruz fires back at Jeb  Bush ÛÏWe lose be...
# 4048  This is the first year the Forest Service spen...
# 3086  lightseraphs pissed at you and could have thei...
# 272        Im gonna fight Taylor as soon as I get there
# 7462  NicolaClements4 IÛªm not sure that covering m...
# 4778  kabwandi Breaking news Unconfirmed I just hear...
# 260   The annihilation of Jeb Christie  Kasich is le...
# 2921                Wtf this mom just drowned her child
# 2162  MayorofLondon pls reduce cyclist deaths with a...
# 4818             DoctorDryadma mass murder here we come
#
#                                              clean_text
# 1386  ted cruz fire back jeb bush lose republican li...
# 4048  first year forest service spent half annual bu...
# 3086      lightseraphs pissed could pikachu electrocute
# 272                      im gonna fight taylor soon get
# 7462  nicolaclements sure covering head wound scab s...
# 4778  kabwandi breaking news unconfirmed heard loud ...
# 260   annihilation jeb christie kasich le hour away ...
# 2921                              wtf mom drowned child
# 2162  mayoroflondon pls reduce cyclist death compuls...
# 4818                     doctordryadma mass murder come

# %% [markdown]
# ## 2-2. Word Tokenization
# - tokenize the clean text column

# %%
train['tokens']=train['clean_text'].apply(lambda x: word_tokenize(x))
test['tokens'] = test['clean_text'].apply(lambda x: word_tokenize(x))

# %%
train.head(5)
# Out:
#              keyword                                               text  \
# 1386    bush%20fires  Ted Cruz fires back at Jeb  Bush ÛÏWe lose be...
# 4048  forest%20fires  This is the first year the Forest Service spen...
# 3086     electrocute  lightseraphs pissed at you and could have thei...
# 272       apocalypse       Im gonna fight Taylor as soon as I get there
# 7462          wounds  NicolaClements4 IÛªm not sure that covering m...
#
#       target                                         clean_text  \
# 1386       0  ted cruz fire back jeb bush lose republican li...
# 4048       1  first year forest service spent half annual bu...
# 3086       0      lightseraphs pissed could pikachu electrocute
# 272        0                     im gonna fight taylor soon get
# 7462       0  nicolaclements sure covering head wound scab s...
#
#                                                  tokens
# 1386  [ted, cruz, fire, back, jeb, bush, lose, repub...
# 4048  [first, year, forest, service, spent, half, an...
# 3086  [lightseraphs, pissed, could, pikachu, electro...
# 272             [im, gon, na, fight, taylor, soon, get]
# 7462  [nicolaclements, sure, covering, head, wound, ...

# %% [markdown]
# ## 2-3. Word2Vec
# - convert our data(words) into vectors

# %%
#first, create a list corpus which we would be using to train word2vec mappings
def fn_pre_process_data(doc):
    for rec in doc:
        yield gensim.utils.simple_preprocess(rec)

corpus = list(fn_pre_process_data(train['clean_text']))
corpus += list(fn_pre_process_data(test['clean_text']))

# %%
#inititate the embedding model, we will come back to the passed arguments later
print('initiated ...')
wv_model = Word2Vec(corpus,vector_size=150,window=3,min_count=2)
#wv_model.build_vocab(corpus)
wv_model.train(corpus,total_examples=len(corpus),epochs=10)
#wv_model.save(data_path + 'word2vec.model')
# Out:
# initiated ...
# (581368, 681810)

# %%
# convert the train and text tokens
def get_word_embeddings(token_list,vector,k=150):
    if len(token_list) < 1:
        return np.zeros(k)
    else:
        vector = vector.wv['word']
        vectorized = [vector if word in vector else np.random.rand(k) for word in token_list] 
    
    sum = np.sum(vectorized,axis=0)
    ## return the average
    return sum/len(vectorized)       

def get_embeddings(tokens,vector):
        embeddings = tokens.apply(lambda x: get_word_embeddings(x, wv_model))
        return list(embeddings)

# %%
train_embeddings = get_embeddings(train['tokens'],wv_model)
test_embeddings = get_embeddings(test['tokens'],wv_model)
# Out:
# <ipython-input-18-a37b903ea56e>:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   vectorized = [vector if word in vector else np.random.rand(k) for word in token_list]

# %% [markdown]
# # 3. Model
# ## Contents
# - train the model
#     - RidgeClassifierCV
#     - sgd classifier
#     - BernoulliNB
#     - RandomForest
#
# ## Model Description
# --------------
# ### Ensemble
# - Combine the predictions of several base estimators built with a given learning algorithm
#     - in order to improve generalizability / robustness over a single estimator.
# - Boosting of Ensemble types
#
# ### Performance - f1-score

# %% [markdown]
# ## 3-2. Train the model

# %%
MLA = [
    #Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),
    
    #GLM
    linear_model.PassiveAggressiveClassifier(),
    linear_model.RidgeClassifierCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),
    
    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),
    
    #Nearest Neighbor
    neighbors.KNeighborsClassifier(),
    
    #Trees    
    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier(),

    XGBClassifier(),
    CatBoostClassifier()  
    ]

# %% [markdown]
# # Comapring all MLA
# - precision
# - recall
# - accuracy
# - f1-score

# %%
train_embeddings = np.array(train_embeddings)
test_embeddings = np.array(test_embeddings)

# %%
# Comparing all machine learning algorithms
from sklearn.metrics import mean_squared_error,confusion_matrix, precision_score, recall_score, auc,roc_curve

row_index = 0
MLA_columns = []
MLA_compare = pd.DataFrame(columns = MLA_columns)

for alg in MLA:
    predicted = alg.fit(train_embeddings, train['target']).predict(test_embeddings)
    fp, tp, th = roc_curve(test['target'], predicted)

    MLA_name = alg.__class__.__name__
    MLA_compare.loc[row_index,'MLA used'] = MLA_name
    MLA_compare.loc[row_index, 'Train Accuracy'] = round(alg.score(train_embeddings, train['target']), 4)
    MLA_compare.loc[row_index, 'Test Accuracy'] = round(alg.score(test_embeddings, test['target']), 4)
    
    
    recall = recall_score(test['target'], predicted)
    precision = precision_score(test['target'], predicted)
    MLA_compare.loc[row_index, 'Precission'] = precision
    MLA_compare.loc[row_index, 'Recall'] = recall
    MLA_compare.loc[row_index, 'F1-score'] = round((2*precision*recall)/(precision+recall),4)
    MLA_compare.loc[row_index, 'AUC'] = auc(fp, tp)

    row_index+=1
# Out:
# /Users/mac/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-22-f8127daba2cd>:22: RuntimeWarning: invalid value encountered in double_scalars
#   MLA_compare.loc[row_index, 'F1-score'] = round((2*precision*recall)/(precision+recall),4)
# /Users/mac/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:55:06] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#
# 50:	learn: 0.6650497	total: 762ms	remaining: 14.2s
# 51:	learn: 0.6646611	total: 775ms	remaining: 14.1s
# 52:	learn: 0.6641631	total: 789ms	remaining: 14.1s
# 53:	learn: 0.6637820	total: 802ms	remaining: 14.1s
# 54:	learn: 0.6633768	total: 817ms	remaining: 14s
# 55:	learn: 0.6629535	total: 836ms	remaining: 14.1s
# 56:	learn: 0.6625237	total: 852ms	remaining: 14.1s
# 57:	learn: 0.6622590	total: 866ms	remaining: 14.1s
# 58:	learn: 0.6618713	total: 879ms	remaining: 14s
# 59:	learn: 0.6615923	total: 893ms	remaining: 14s
# 60:	learn: 0.6612019	total: 906ms	remaining: 13.9s
# 61:	learn: 0.6607700	total: 920ms	remaining: 13.9s
# 62:	learn: 0.6603790	total: 934ms	remaining: 13.9s
# 63:	learn: 0.6600200	total: 948ms	remaining: 13.9s
# 64:	learn: 0.6596122	total: 963ms	remaining: 13.8s
# 65:	learn: 0.6591816	total: 978ms	remaining: 13.8s
# 66:	learn: 0.6588497	total: 995ms	remaining: 13.9s
# 67:	learn: 0.6584759	total: 1.01s	remaining: 13.9s
# 68:	learn: 0.6580212	total: 1.03s	remaining: 13.9s
# 69:	learn: 0.6576242	total: 1.05s	remaining: 14s
# 70:	learn: 0.6573167	total: 1.07s	remaining: 14s
# 71:	learn: 0.6569994	total: 1.09s	remaining: 14s
# 72:	learn: 0.6566771	total: 1.11s	remaining: 14s
# 73:	learn: 0.6563248	total: 1.12s	remaining: 14.1s
# 74:	learn: 0.6558984	total: 1.14s	remaining: 14s
# 75:	learn: 0.6555165	total: 1.15s	remaining: 14s
# 76:	learn: 0.6552704	total: 1.16s	remaining: 13.9s
# 77:	learn: 0.6548879	total: 1.18s	remaining: 13.9s
# 78:	learn: 0.6545543	total: 1.19s	remaining: 13.9s
# 79:	learn: 0.6541986	total: 1.2s	remaining: 13.9s
# 80:	learn: 0.6538326	total: 1.22s	remaining: 13.8s
# 81:	learn: 0.6536013	total: 1.23s	remaining: 13.8s
# 82:	learn: 0.6532871	total: 1.25s	remaining: 13.8s
# 83:	learn: 0.6530431	total: 1.27s	remaining: 13.8s
# 84:	learn: 0.6527711	total: 1.28s	remaining: 13.8s
# 85:	learn: 0.6524935	total: 1.3s	remaining: 13.8s
# 86:	learn: 0.6521199	total: 1.31s	remaining: 13.8s
# 87:	learn: 0.6517472	total: 1.33s	remaining: 13.8s
# 88:	learn: 0.6515449	total: 1.34s	remaining: 13.7s
# 89:	learn: 0.6512470	total: 1.35s	remaining: 13.7s
# 90:	learn: 0.6508342	total: 1.37s	remaining: 13.7s
# 91:	learn: 0.6503107	total: 1.38s	remaining: 13.7s
# 92:	learn: 0.6499760	total: 1.4s	remaining: 13.6s
# 93:	learn: 0.6496682	total: 1.41s	remaining: 13.6s
# 94:	learn: 0.6492894	total: 1.42s	remaining: 13.6s
# 95:	learn: 0.6488695	total: 1.44s	remaining: 13.5s
# 96:	learn: 0.6485410	total: 1.45s	remaining: 13.5s
# 97:	learn: 0.6482532	total: 1.47s	remaining: 13.5s
# 98:	learn: 0.6478625	total: 1.48s	remaining: 13.5s
# 99:	learn: 0.6475692	total: 1.5s	remaining: 13.5s
# 100:	learn: 0.6472238	total: 1.51s	remaining: 13.4s
# 101:	learn: 0.6469048	total: 1.52s	remaining: 13.4s
# 102:	learn: 0.6464611	total: 1.54s	remaining: 13.4s
# 103:	learn: 0.6462143	total: 1.55s	remaining: 13.4s
# 104:	learn: 0.6458056	total: 1.56s	remaining: 13.3s
# 105:	learn: 0.6454588	total: 1.58s	remaining: 13.3s
# 106:	learn: 0.6450696	total: 1.59s	remaining: 13.3s
# 107:	learn: 0.6447805	total: 1.6s	remaining: 13.2s
# 108:	learn: 0.6445031	total: 1.62s	remaining: 13.2s
# 109:	learn: 0.6442054	total: 1.63s	remaining: 13.2s
# 110:	learn: 0.6439139	total: 1.65s	remaining: 13.2s
# 111:	learn: 0.6436449	total: 1.66s	remaining: 13.2s
# 112:	learn: 0.6432986	total: 1.67s	remaining: 13.1s
# 113:	learn: 0.6429222	total: 1.69s	remaining: 13.1s
# 114:	learn: 0.6425985	total: 1.7s	remaining: 13.1s
# 115:	learn: 0.6424278	total: 1.72s	remaining: 13.1s
# 116:	learn: 0.6421356	total: 1.73s	remaining: 13s
# 117:	learn: 0.6417482	total: 1.74s	remaining: 13s
# 118:	learn: 0.6413563	total: 1.75s	remaining: 13s
# 119:	learn: 0.6410390	total: 1.77s	remaining: 13s
# 120:	learn: 0.6406017	total: 1.78s	remaining: 13s
# 121:	learn: 0.6402198	total: 1.8s	remaining: 12.9s
# 122:	learn: 0.6399938	total: 1.81s	remaining: 12.9s
# 123:	learn: 0.6397095	total: 1.82s	remaining: 12.9s
# 124:	learn: 0.6393748	total: 1.84s	remaining: 12.9s
# 125:	learn: 0.6391243	total: 1.85s	remaining: 12.8s
# 126:	learn: 0.6387802	total: 1.86s	remaining: 12.8s
# 127:	learn: 0.6383560	total: 1.88s	remaining: 12.8s
# 128:	learn: 0.6380392	total: 1.89s	remaining: 12.8s
# 129:	learn: 0.6376675	total: 1.91s	remaining: 12.8s
# 130:	learn: 0.6373250	total: 1.92s	remaining: 12.8s
# 131:	learn: 0.6369905	total: 1.94s	remaining: 12.7s
# 132:	learn: 0.6367424	total: 1.95s	remaining: 12.7s
# 133:	learn: 0.6364158	total: 1.96s	remaining: 12.7s
# 134:	learn: 0.6360945	total: 1.98s	remaining: 12.7s
# 135:	learn: 0.6357492	total: 1.99s	remaining: 12.6s
# 136:	learn: 0.6355440	total: 2s	remaining: 12.6s
# 137:	learn: 0.6352106	total: 2.02s	remaining: 12.6s
# 138:	learn: 0.6348984	total: 2.03s	remaining: 12.6s
# 139:	learn: 0.6346275	total: 2.04s	remaining: 12.5s
# 140:	learn: 0.6342601	total: 2.06s	remaining: 12.5s
# 141:	learn: 0.6339217	total: 2.07s	remaining: 12.5s
# 142:	learn: 0.6335686	total: 2.09s	remaining: 12.5s
# 143:	learn: 0.6332811	total: 2.1s	remaining: 12.5s
# 376:	learn: 0.5641212	total: 5.52s	remaining: 9.12s
# 377:	learn: 0.5638796	total: 5.53s	remaining: 9.11s
# 378:	learn: 0.5636218	total: 5.55s	remaining: 9.09s
# 379:	learn: 0.5632752	total: 5.56s	remaining: 9.07s
# 380:	learn: 0.5629010	total: 5.58s	remaining: 9.06s
# 381:	learn: 0.5626664	total: 5.59s	remaining: 9.04s
# 382:	learn: 0.5623557	total: 5.6s	remaining: 9.03s
# 383:	learn: 0.5620720	total: 5.62s	remaining: 9.01s
# 384:	learn: 0.5618092	total: 5.63s	remaining: 8.99s
# 385:	learn: 0.5614973	total: 5.65s	remaining: 8.99s
# 386:	learn: 0.5611535	total: 5.67s	remaining: 8.97s
# 387:	learn: 0.5608208	total: 5.68s	remaining: 8.96s
# 388:	learn: 0.5605415	total: 5.7s	remaining: 8.95s
# 389:	learn: 0.5602251	total: 5.71s	remaining: 8.94s
# 390:	learn: 0.5599799	total: 5.73s	remaining: 8.92s
# 391:	learn: 0.5596908	total: 5.75s	remaining: 8.91s
# 392:	learn: 0.5594381	total: 5.76s	remaining: 8.9s
# 393:	learn: 0.5591377	total: 5.78s	remaining: 8.89s
# 394:	learn: 0.5588199	total: 5.8s	remaining: 8.88s
# 395:	learn: 0.5585384	total: 5.81s	remaining: 8.87s
# 396:	learn: 0.5583202	total: 5.83s	remaining: 8.85s
# 397:	learn: 0.5580002	total: 5.84s	remaining: 8.84s
# 398:	learn: 0.5576345	total: 5.86s	remaining: 8.82s
# 399:	learn: 0.5573559	total: 5.87s	remaining: 8.81s
# 400:	learn: 0.5570199	total: 5.89s	remaining: 8.79s
# 401:	learn: 0.5567462	total: 5.9s	remaining: 8.78s
# 402:	learn: 0.5564190	total: 5.92s	remaining: 8.76s
# 403:	learn: 0.5562016	total: 5.93s	remaining: 8.75s
# 404:	learn: 0.5558017	total: 5.95s	remaining: 8.74s
# 405:	learn: 0.5554211	total: 5.96s	remaining: 8.72s
# 406:	learn: 0.5552065	total: 5.98s	remaining: 8.71s
# 407:	learn: 0.5549144	total: 5.99s	remaining: 8.7s
# 408:	learn: 0.5545762	total: 6.01s	remaining: 8.68s
# 409:	learn: 0.5542185	total: 6.02s	remaining: 8.67s
# 410:	learn: 0.5538531	total: 6.04s	remaining: 8.65s
# 411:	learn: 0.5535123	total: 6.05s	remaining: 8.64s
# 412:	learn: 0.5532424	total: 6.07s	remaining: 8.62s
# 413:	learn: 0.5528805	total: 6.08s	remaining: 8.61s
# 414:	learn: 0.5525038	total: 6.09s	remaining: 8.59s
# 415:	learn: 0.5521298	total: 6.11s	remaining: 8.57s
# 416:	learn: 0.5519637	total: 6.12s	remaining: 8.56s
# 417:	learn: 0.5517069	total: 6.13s	remaining: 8.54s
# 418:	learn: 0.5514331	total: 6.15s	remaining: 8.53s
# 419:	learn: 0.5511427	total: 6.16s	remaining: 8.51s
# 420:	learn: 0.5507388	total: 6.17s	remaining: 8.49s
# 421:	learn: 0.5504140	total: 6.19s	remaining: 8.48s
# 699:	learn: 0.4610740	total: 10.3s	remaining: 4.42s
# 700:	learn: 0.4607020	total: 10.3s	remaining: 4.41s
# 701:	learn: 0.4603888	total: 10.3s	remaining: 4.39s
# 702:	learn: 0.4602175	total: 10.4s	remaining: 4.38s
# 703:	learn: 0.4599139	total: 10.4s	remaining: 4.36s
# 704:	learn: 0.4596709	total: 10.4s	remaining: 4.35s
# 705:	learn: 0.4593384	total: 10.4s	remaining: 4.33s
# 706:	learn: 0.4590490	total: 10.4s	remaining: 4.32s
# 707:	learn: 0.4587850	total: 10.4s	remaining: 4.3s
# 708:	learn: 0.4584715	total: 10.5s	remaining: 4.29s
# 709:	learn: 0.4582280	total: 10.5s	remaining: 4.28s
# 710:	learn: 0.4580063	total: 10.5s	remaining: 4.26s
# 711:	learn: 0.4577031	total: 10.5s	remaining: 4.25s
# 712:	learn: 0.4574731	total: 10.5s	remaining: 4.23s
# 713:	learn: 0.4571544	total: 10.5s	remaining: 4.22s
# 714:	learn: 0.4569058	total: 10.5s	remaining: 4.2s
# 715:	learn: 0.4565973	total: 10.6s	remaining: 4.19s
# 716:	learn: 0.4563472	total: 10.6s	remaining: 4.17s
# 717:	learn: 0.4560498	total: 10.6s	remaining: 4.16s
# 718:	learn: 0.4557845	total: 10.6s	remaining: 4.14s
# 719:	learn: 0.4554867	total: 10.6s	remaining: 4.13s
# 720:	learn: 0.4551718	total: 10.6s	remaining: 4.11s
# 721:	learn: 0.4548390	total: 10.6s	remaining: 4.1s
# 722:	learn: 0.4545368	total: 10.7s	remaining: 4.08s
# 723:	learn: 0.4543553	total: 10.7s	remaining: 4.07s
# 724:	learn: 0.4540917	total: 10.7s	remaining: 4.05s
# 725:	learn: 0.4537670	total: 10.7s	remaining: 4.04s
# 726:	learn: 0.4533776	total: 10.7s	remaining: 4.02s
# 727:	learn: 0.4530899	total: 10.7s	remaining: 4.01s
# 728:	learn: 0.4527631	total: 10.7s	remaining: 3.99s
# 729:	learn: 0.4523861	total: 10.8s	remaining: 3.98s
# 730:	learn: 0.4520636	total: 10.8s	remaining: 3.96s
# 731:	learn: 0.4517694	total: 10.8s	remaining: 3.95s
# 732:	learn: 0.4514345	total: 10.8s	remaining: 3.93s
# 733:	learn: 0.4511502	total: 10.8s	remaining: 3.92s
# 734:	learn: 0.4508905	total: 10.8s	remaining: 3.9s
# 735:	learn: 0.4505407	total: 10.8s	remaining: 3.89s
# 736:	learn: 0.4502422	total: 10.9s	remaining: 3.87s
# 737:	learn: 0.4498875	total: 10.9s	remaining: 3.86s
# 738:	learn: 0.4495717	total: 10.9s	remaining: 3.84s
# 739:	learn: 0.4491802	total: 10.9s	remaining: 3.83s
# 740:	learn: 0.4488546	total: 10.9s	remaining: 3.81s
# 741:	learn: 0.4485418	total: 10.9s	remaining: 3.8s
# 742:	learn: 0.4482659	total: 10.9s	remaining: 3.79s
# 743:	learn: 0.4479674	total: 11s	remaining: 3.77s
# 744:	learn: 0.4476921	total: 11s	remaining: 3.75s
# 745:	learn: 0.4474451	total: 11s	remaining: 3.74s
# 839:	learn: 0.4213085	total: 12.4s	remaining: 2.36s
# 840:	learn: 0.4211241	total: 12.4s	remaining: 2.35s
# 841:	learn: 0.4208252	total: 12.4s	remaining: 2.33s
# 842:	learn: 0.4205644	total: 12.4s	remaining: 2.32s
# 843:	learn: 0.4202942	total: 12.5s	remaining: 2.3s
# 844:	learn: 0.4200728	total: 12.5s	remaining: 2.29s
# 845:	learn: 0.4197815	total: 12.5s	remaining: 2.27s
# 846:	learn: 0.4194827	total: 12.5s	remaining: 2.26s
# 847:	learn: 0.4192429	total: 12.6s	remaining: 2.25s
# 848:	learn: 0.4189220	total: 12.6s	remaining: 2.24s
# 849:	learn: 0.4186566	total: 12.6s	remaining: 2.22s
# 850:	learn: 0.4185183	total: 12.6s	remaining: 2.21s
# 851:	learn: 0.4182414	total: 12.6s	remaining: 2.2s
# 852:	learn: 0.4180292	total: 12.7s	remaining: 2.18s
# 853:	learn: 0.4177615	total: 12.7s	remaining: 2.17s
# 854:	learn: 0.4174353	total: 12.7s	remaining: 2.15s
# 855:	learn: 0.4172226	total: 12.7s	remaining: 2.14s
# 856:	learn: 0.4170017	total: 12.7s	remaining: 2.12s
# 857:	learn: 0.4166566	total: 12.7s	remaining: 2.11s
# 858:	learn: 0.4163701	total: 12.8s	remaining: 2.09s
# 859:	learn: 0.4161093	total: 12.8s	remaining: 2.08s
# 860:	learn: 0.4158680	total: 12.8s	remaining: 2.07s
# 861:	learn: 0.4156802	total: 12.8s	remaining: 2.06s
# 862:	learn: 0.4154286	total: 12.9s	remaining: 2.04s
# 863:	learn: 0.4151650	total: 12.9s	remaining: 2.02s
# 864:	learn: 0.4149598	total: 12.9s	remaining: 2.01s
# 865:	learn: 0.4146150	total: 12.9s	remaining: 2s
# 866:	learn: 0.4143261	total: 12.9s	remaining: 1.98s
# 867:	learn: 0.4139831	total: 12.9s	remaining: 1.97s
# 868:	learn: 0.4137969	total: 13s	remaining: 1.95s
# 869:	learn: 0.4135173	total: 13s	remaining: 1.94s
# 870:	learn: 0.4131474	total: 13s	remaining: 1.92s
# 871:	learn: 0.4129028	total: 13s	remaining: 1.91s
# 872:	learn: 0.4127053	total: 13s	remaining: 1.89s
# 873:	learn: 0.4124152	total: 13s	remaining: 1.88s
# 874:	learn: 0.4121828	total: 13s	remaining: 1.86s
# 875:	learn: 0.4118674	total: 13.1s	remaining: 1.85s
# 876:	learn: 0.4116970	total: 13.1s	remaining: 1.83s
# 877:	learn: 0.4113709	total: 13.1s	remaining: 1.82s
# 878:	learn: 0.4110524	total: 13.1s	remaining: 1.8s
# 879:	learn: 0.4108062	total: 13.1s	remaining: 1.79s
# 880:	learn: 0.4105706	total: 13.1s	remaining: 1.77s
# 881:	learn: 0.4102902	total: 13.1s	remaining: 1.76s
# 882:	learn: 0.4101939	total: 13.2s	remaining: 1.74s
# 883:	learn: 0.4098723	total: 13.2s	remaining: 1.73s
# 884:	learn: 0.4096758	total: 13.2s	remaining: 1.71s
# 885:	learn: 0.4094387	total: 13.2s	remaining: 1.7s
# 886:	learn: 0.4092489	total: 13.2s	remaining: 1.68s
# 887:	learn: 0.4090050	total: 13.2s	remaining: 1.67s
# 888:	learn: 0.4087009	total: 13.3s	remaining: 1.65s
# 889:	learn: 0.4084360	total: 13.3s	remaining: 1.64s
# 890:	learn: 0.4082099	total: 13.3s	remaining: 1.62s
# 891:	learn: 0.4079912	total: 13.3s	remaining: 1.61s
# 892:	learn: 0.4077140	total: 13.3s	remaining: 1.59s
# 893:	learn: 0.4074789	total: 13.3s	remaining: 1.58s
# 894:	learn: 0.4072974	total: 13.3s	remaining: 1.57s
# 895:	learn: 0.4070931	total: 13.4s	remaining: 1.55s
# 896:	learn: 0.4069100	total: 13.4s	remaining: 1.54s
# 897:	learn: 0.4066344	total: 13.5s	remaining: 1.53s
# 898:	learn: 0.4064449	total: 13.5s	remaining: 1.51s
# 899:	learn: 0.4061891	total: 13.5s	remaining: 1.5s
# 900:	learn: 0.4059136	total: 13.5s	remaining: 1.48s
# 901:	learn: 0.4057322	total: 13.5s	remaining: 1.47s
# 902:	learn: 0.4054720	total: 13.5s	remaining: 1.45s
# 903:	learn: 0.4051813	total: 13.5s	remaining: 1.44s
# 904:	learn: 0.4049241	total: 13.6s	remaining: 1.42s
# 905:	learn: 0.4046907	total: 13.6s	remaining: 1.41s
# 906:	learn: 0.4044720	total: 13.6s	remaining: 1.39s
# 907:	learn: 0.4042202	total: 13.6s	remaining: 1.38s
# 908:	learn: 0.4039095	total: 13.6s	remaining: 1.36s
# 909:	learn: 0.4036419	total: 13.6s	remaining: 1.35s
# 910:	learn: 0.4034345	total: 13.6s	remaining: 1.33s
# 911:	learn: 0.4031630	total: 13.7s	remaining: 1.32s
# 912:	learn: 0.4029907	total: 13.7s	remaining: 1.3s
# 913:	learn: 0.4027625	total: 13.7s	remaining: 1.29s
# 914:	learn: 0.4026032	total: 13.7s	remaining: 1.27s
# 915:	learn: 0.4023899	total: 13.7s	remaining: 1.26s
# 916:	learn: 0.4021801	total: 13.7s	remaining: 1.24s
# 917:	learn: 0.4019674	total: 13.8s	remaining: 1.23s
# 918:	learn: 0.4017412	total: 13.8s	remaining: 1.21s
# 919:	learn: 0.4015391	total: 13.8s	remaining: 1.2s
# 920:	learn: 0.4013066	total: 13.8s	remaining: 1.18s
# 921:	learn: 0.4010170	total: 13.8s	remaining: 1.17s
# 922:	learn: 0.4007321	total: 13.8s	remaining: 1.15s
# 923:	learn: 0.4004894	total: 13.8s	remaining: 1.14s
# 924:	learn: 0.4001885	total: 13.9s	remaining: 1.12s
# 925:	learn: 0.3999532	total: 13.9s	remaining: 1.11s
# 926:	learn: 0.3996962	total: 13.9s	remaining: 1.09s
# 927:	learn: 0.3994300	total: 13.9s	remaining: 1.08s
# 928:	learn: 0.3991902	total: 13.9s	remaining: 1.06s
# 929:	learn: 0.3989085	total: 13.9s	remaining: 1.05s
# 930:	learn: 0.3986531	total: 13.9s	remaining: 1.03s
# 931:	learn: 0.3983997	total: 14s	remaining: 1.02s
# 980:	learn: 0.3865167	total: 14.7s	remaining: 285ms
# 981:	learn: 0.3862816	total: 14.7s	remaining: 270ms
# 982:	learn: 0.3861005	total: 14.7s	remaining: 255ms
# 983:	learn: 0.3858245	total: 14.7s	remaining: 240ms
# 984:	learn: 0.3856464	total: 14.8s	remaining: 225ms
# 985:	learn: 0.3853945	total: 14.8s	remaining: 210ms
# 986:	learn: 0.3850988	total: 14.8s	remaining: 195ms
# 987:	learn: 0.3847991	total: 14.8s	remaining: 180ms
# 988:	learn: 0.3845339	total: 14.8s	remaining: 165ms
# 989:	learn: 0.3842733	total: 14.8s	remaining: 150ms
# 990:	learn: 0.3840425	total: 14.9s	remaining: 135ms
# 991:	learn: 0.3839154	total: 14.9s	remaining: 120ms
# 992:	learn: 0.3836763	total: 14.9s	remaining: 105ms
# 993:	learn: 0.3834552	total: 14.9s	remaining: 89.9ms
# 994:	learn: 0.3832902	total: 14.9s	remaining: 75ms
# 995:	learn: 0.3830414	total: 14.9s	remaining: 60ms
# 996:	learn: 0.3827389	total: 15s	remaining: 45ms
# 997:	learn: 0.3824333	total: 15s	remaining: 30ms
# 998:	learn: 0.3821840	total: 15s	remaining: 15ms
# 999:	learn: 0.3819480	total: 15s	remaining: 0us

# %%
# f1-score 기준 정렬
MLA_compare.sort_values(by = ['F1-score'], ascending = False, inplace = True)    
MLA_compare
# Out:
#                        MLA used  Train Accuracy  Test Accuracy  Precission  \
# 5   PassiveAggressiveClassifier          0.4342         0.4183    0.418253
# 8                    Perceptron          0.4340         0.4183    0.418253
# 10                   GaussianNB          0.5358         0.5108    0.444215
# 13          ExtraTreeClassifier          1.0000         0.5128    0.423133
# 12       DecisionTreeClassifier          1.0000         0.5036    0.413643
# 0            AdaBoostClassifier          0.6202         0.5167    0.418451
# 11         KNeighborsClassifier          0.6906         0.5102    0.410214
# 14                XGBClassifier          1.0000         0.5240    0.419414
# 3    GradientBoostingClassifier          0.7685         0.5561    0.448819
# 15           CatBoostClassifier          0.9941         0.5568    0.448925
# 1             BaggingClassifier          0.9852         0.5378    0.416040
# 6             RidgeClassifierCV          0.5762         0.5489    0.401575
# 4        RandomForestClassifier          1.0000         0.5601    0.426009
# 2          ExtraTreesClassifier          1.0000         0.5634    0.432692
# 7                 SGDClassifier          0.5672         0.5739    0.125000
# 9                   BernoulliNB          0.5675         0.5817    0.000000
#
#       Recall  F1-score       AUC
# 5   1.000000    0.5898  0.500000
# 8   1.000000    0.5898  0.500000
# 10  0.675039    0.5358  0.533908
# 13  0.453689    0.4379  0.504497
# 12  0.447410    0.4299  0.495714
# 0   0.398744    0.4084  0.500162
# 11  0.390895    0.4003  0.493416
# 14  0.359498    0.3872  0.500855
# 3   0.268446    0.3360  0.515713
# 15  0.262166    0.3310  0.515395
# 1   0.260597    0.3205  0.498808
# 6   0.160126    0.2290  0.494284
# 4   0.149137    0.2209  0.502334
# 2   0.141287    0.2130  0.504052
# 7   0.003140    0.0061  0.493669
# 9   0.000000       NaN  0.500000
